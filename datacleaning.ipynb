# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("data/Yelp_Reviews.csv")
df.head()
# Out:
#    Unnamed: 0             business_id cool        date  funny  \
# 0           1  pomGBqfbxcqPv14c3XH-ZQ    0  2012-11-13      0
# 1           2  jtQARsP6P-LbkyjbO1qNGg    1  2014-10-23      1
# 2           4  Ums3gaP2qM3W1XcA5r6SsQ    0  2014-09-05      0
# 3           5  vgfcTvK81oD4r50NMjU2Ag    0  2011-02-25      0
# 4          10  yFumR3CWzpfvTH2FCthvVw    0  2016-06-15      0
#
#                 review_id  stars  \
# 0  dDl8zu1vWPdKGihJrwQbpw    5.0
# 1  LZp4UX5zK3e-c5ZGSeo3kA    1.0
# 2  jsDu6QEJHbwP2Blom1PLCA    5.0
# 3  pfavA0hr3nyqO61oupj-lA    NaN
# 4  STiFMww2z31siPY7BWNC2g    5.0
#
#                                                 text  useful  \
# 0  I love this place! My fiance And I go here atl...       0
# 1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 2  Delicious healthy food. The steak is amazing. ...       0
# 3  This place sucks. The customer service is horr...       2
# 4  I have been an Emerald Club member for a numbe...       0
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2610 entries, 0 to 2609
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   2610 non-null   int64
#  1   business_id  2610 non-null   object
#  2   cool         2608 non-null   object
#  3   date         2610 non-null   object
#  4   funny        2610 non-null   int64
#  5   review_id    2610 non-null   object
#  6   stars        2607 non-null   float64
#  7   text         2610 non-null   object
#  8   useful       2610 non-null   int64
#  9   user_id      2610 non-null   object
# dtypes: float64(1), int64(3), object(6)
# memory usage: 204.0+ KB

# %%
#Lambda function
multiply = lambda x: x*2
print(multiply(4))
# Out:
# 8

# %%
df["text"].apply(lambda text:len(text.split()))
# Out:
# 0        58
# 1        30
# 2        30
# 3        82
# 4        32
#        ...
# 2605     61
# 2606     43
# 2607     79
# 2608    185
# 2609     42
# Name: text, Length: 2610, dtype: int64

# %%
df["review.length"] = df["text"].apply(lambda text:len(text.split()))
df.head()
# Out:
#    Unnamed: 0             business_id cool        date  funny  \
# 0           1  pomGBqfbxcqPv14c3XH-ZQ    0  2012-11-13      0
# 1           2  jtQARsP6P-LbkyjbO1qNGg    1  2014-10-23      1
# 2           4  Ums3gaP2qM3W1XcA5r6SsQ    0  2014-09-05      0
# 3           5  vgfcTvK81oD4r50NMjU2Ag    0  2011-02-25      0
# 4          10  yFumR3CWzpfvTH2FCthvVw    0  2016-06-15      0
#
#                 review_id  stars  \
# 0  dDl8zu1vWPdKGihJrwQbpw    5.0
# 1  LZp4UX5zK3e-c5ZGSeo3kA    1.0
# 2  jsDu6QEJHbwP2Blom1PLCA    5.0
# 3  pfavA0hr3nyqO61oupj-lA    NaN
# 4  STiFMww2z31siPY7BWNC2g    5.0
#
#                                                 text  useful  \
# 0  I love this place! My fiance And I go here atl...       0
# 1  Terrible. Dry corn bread. Rib tips were all fa...       3
# 2  Delicious healthy food. The steak is amazing. ...       0
# 3  This place sucks. The customer service is horr...       2
# 4  I have been an Emerald Club member for a numbe...       0
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'business_id', 'cool', 'date', 'funny', 'review_id',
#        'stars', 'text', 'useful', 'user_id', 'review.length'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2610 entries, 0 to 2609
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     2610 non-null   int64
#  1   business_id    2610 non-null   object
#  2   cool           2608 non-null   object
#  3   date           2610 non-null   object
#  4   funny          2610 non-null   int64
#  5   review_id      2610 non-null   object
#  6   stars          2607 non-null   float64
#  7   text           2610 non-null   object
#  8   useful         2610 non-null   int64
#  9   user_id        2610 non-null   object
#  10  review.length  2610 non-null   int64
# dtypes: float64(1), int64(4), object(6)
# memory usage: 224.4+ KB

# %%
df.duplicates()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-55-1516c86afcb0> in <module>
# ----> 1 df.duplicates()
#
# c:\Users\beaut\anaconda3\envs\learn-env\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'duplicates'

# %%
df.duplicated() .sum()  #this are duplicated rows
# Out:
# 333

# %%
df.duplicated() .value_counts() # this are  ones that are duplicated and not duplicated
# Out:
# False    2277
# True      333
# dtype: int64

# %%
df[df.duplicated()].head() #basically the first five rows
# Out:
#       Unnamed: 0             business_id cool        date  funny  \
# 1411        4252  fIuquIgWrkNEM5yvYSHPgw    2  2014-08-05      0
# 1412        3028  _JD_U3pZDynB6l8swzVlQA    0  2017-12-17      0
# 1414        3046  yQUXMWSA8H7wvkLa4iCD8g    0  2014-08-28      0
# 1417        2322  1lLJDy73uBp_I2LJ0B0Fkw    1  2011-09-09      0
# 1419         794  XXW_OFaYQkkGOGniujZFHg    0  2013-12-04      0
#
#                    review_id  stars  \
# 1411  X4glBKsOvs6fgjHNJ0IUjw    5.0
# 1412  iuVHqEglBCmL1lAbw8B2Ow    5.0
# 1414  KmKCR_cHmAYA12Uy3XPHCA    2.0
# 1417  03dNKEDriDeZ8poYbiNyxQ    5.0
# 1419  XxsMdJl8OTgeq5iEhp4JLQ    5.0
#
#                                                    text  useful  \
# 1411  What a compassionate and thorough professional...       3
# 1412  Had to switch barbers because I moved and the ...       0
# 1414  Rude waitress and slow service. No offers for ...       1
# 1417  Was here for a party last weekend and had a bl...       0
# ...

# %%
df=df.drop_duplicates()

# %%
df.duplicated() .value_counts()
# Out:
# False    2277
# dtype: int64
